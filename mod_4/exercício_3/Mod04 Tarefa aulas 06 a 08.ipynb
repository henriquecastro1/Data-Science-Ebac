# %% [markdown]
# # Tarefa 03
#
# - Leia os enunciados com atenção
# - Saiba que pode haver mais de uma resposta correta
# - Insira novas células de código sempre que achar necessário
# - Em caso de dúvidas, procure os Tutores
# - Divirta-se :)

# %%
import pandas as pd
import requests

# %% [markdown]
# ####  1) Lendo de APIs
# Vimos em aula como carregar dados públicos do governo através de um API (*Application Programming Interface*). No exemplo de aula, baixamos os dados de pedidos de verificação de limites (PVL) realizados por estados, e selecionamos apenas aqueles referentes ao estado de São Paulo.
#
# 1. Repita os mesmos passos feitos em aula, mas selecione os PVLs realizados por municípios no estado do Rio de Janeiro.
# 2. Quais são os três *status* das solicitações mais frequentes na base? Quais são suas frequências?
# 3. Construa uma nova variável que contenha o ano do **status**. Observe que ```data_status``` vem como tipo *object* no **DataFrame**. Dica: você pode usar o método ```.str``` para transformar o tipo da variável em string, em seguida um método como [**slice()**](https://pandas.pydata.org/docs/reference/api/pandas.Series.str.slice.html) ou [**split()**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.split.html).
# 4. Indique a frequência de cada ano do campo construído no item (3).

# %%
# 1) Seu código aqui
url = 'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl' #inserindo a url em uma variável
r = requests.get(url)

# %%
data_json = r.json()
df = pd.DataFrame(data_json['items'])
df
# Out:
#       id_pleito tipo_interessado      interessado  cod_ibge  uf  \
# 0         15974        Município       Montenegro   4312401  RS
# 1         15977        Município           Gaspar   4205902  SC
# 2         15985        Município       Vale Verde   4322525  RS
# 3          9666           Estado            Ceará        23  CE
# 4          9693        Município     Nova Resende   3145109  MG
# ...         ...              ...              ...       ...  ..
# 4995      27068           Estado          Sergipe        28  SE
# 4996      26744        Município            Itati   4310652  RS
# 4997      31193        Município    Campos Borges   4304101  RS
# 4998      31324        Município           Cacoal   1100049  RO
# 4999      30430        Município  Mogi das Cruzes   3530607  SP
#
#                    num_pvl             status          num_processo  \
# 0                     None           Deferido  19406.000244/2009-02
# 1                     None           Deferido  19406.000245/2003-53
# 2                     None           Deferido  19406.000246/2003-06
# 3                     None           Deferido  17944.001028/2013-30
# 4                     None          Arquivado  17944.001035/2008-74
# ...                    ...                ...                   ...
# 4995  PVL02.002575/2017-01           Deferido  17944.103570/2017-50
# 4996  PVL02.002389/2017-64  Deferido (PVL-IF)                  None
# 4997  PVL02.000504/2019-28  Deferido (PVL-IF)                  None
# 4998  PVL02.000615/2019-34  Deferido (PVL-IF)                  None
# 4999  PVL02.002730/2018-62           Deferido  17944.109920/2018-72
#
#             data_protocolo                tipo_operacao  \
# 0     2011-07-04T03:00:00Z  Operação contratual interna
# 1     2003-10-31T02:00:00Z  Operação contratual interna
# 2     2004-01-28T02:00:00Z  Operação contratual interna
# 3     2013-10-15T03:00:00Z  Operação contratual interna
# 4     2008-08-11T03:00:00Z  Operação contratual interna
# ...                    ...                          ...
# 4995  2017-12-20T14:21:51Z  Operação contratual interna
# 4996                  None  Operação contratual interna
# 4997                  None  Operação contratual interna
# 4998                  None  Operação contratual interna
# 4999  2018-12-18T19:13:21Z  Operação contratual interna
#
#                                           finalidade  \
# 0                                            Provias
# 1                                     Infraestrutura
# 2     Aquisição de máquinas, equipamentos e veículos
# 3                                      BNDES Estados
# 4                          PAC - Saneamento - 2008 B
# ...                                              ...
# 4995                         Renegociação de dívidas
# 4996  Aquisição de máquinas, equipamentos e veículos
# 4997  Aquisição de máquinas, equipamentos e veículos
# 4998                               Aporte de capital
# 4999                           Saneamento para Todos
#
#                           tipo_credor  \
# 0     Instituição Financeira Nacional
# 1     Instituição Financeira Nacional
# 2     Instituição Financeira Nacional
# 3     Instituição Financeira Nacional
# 4     Instituição Financeira Nacional
# ...                               ...
# 4995                            União
# 4996  Instituição Financeira Nacional
# 4997  Instituição Financeira Nacional
# 4998  Instituição Financeira Nacional
# 4999  Instituição Financeira Nacional
#
#                                                  credor moeda         valor  \
# 0                                   Banco do Brasil S/A  Real  3.000000e+06
# 1     Agência de Fomento do Estado de Santa Catarina...  Real  2.800000e+05
# 2                  Banco do Estado do Rio Grande do Sul  Real  3.000000e+05
# 3     Banco Nacional de Desenvolvimento Econômico e ...  Real  1.215000e+08
# 4          Banco de Desenvolvimento de Minas Gerais S/A  Real  5.738000e+05
# ...                                                 ...   ...           ...
# 4995                                              União  Real  8.962460e+08
# 4996  BADESUL Desenvolvimento S.A. - Agência de Fome...  Real  8.000000e+05
# 4997                                Banco do Brasil S/A  Real  3.300000e+05
# 4998                            Caixa Econômica Federal  Real  5.000000e+06
# 4999                            Caixa Econômica Federal  Real  1.196876e+07
#
#       pvl_assoc_divida  pvl_contradado_credor data_status
# 0                    1                      0  27/07/2011
# 1                    1                      0  19/12/2003
# 2                    1                      0  04/02/2004
# 3                    1                      0  22/10/2013
# 4                    0                      0  30/04/2008
# ...                ...                    ...         ...
# 4995                 0                      0  21/12/2017
# 4996                 1                      1  08/06/2018
# 4997                 1                      1  26/04/2019
# 4998                 1                      1  05/08/2019
# 4999                 1                      1  21/12/2018
#
# [5000 rows x 18 columns]

# %%
rio_de_janeiro = df['uf']== 'RJ'

# %%
rio_de_janeiro.value_counts()
# Out:
# uf
# False    4940
# True       60
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['id_pleito', 'tipo_interessado', 'interessado', 'cod_ibge', 'uf',
#        'num_pvl', 'status', 'num_processo', 'data_protocolo', 'tipo_operacao',
#        'finalidade', 'tipo_credor', 'credor', 'moeda', 'valor',
#        'pvl_assoc_divida', 'pvl_contradado_credor', 'data_status'],
#       dtype='object')

# %%
# 2) Seu código aqui
df['status'].value_counts().head(3)
# Out:
# status
# Deferido             2460
# Deferido (PVL-IF)    1270
# Arquivado             360
# Name: count, dtype: int64

# %%
# 3) Seu código aqui
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id_pleito              5000 non-null   int64
#  1   tipo_interessado       5000 non-null   object
#  2   interessado            5000 non-null   object
#  3   cod_ibge               5000 non-null   int64
#  4   uf                     5000 non-null   object
#  5   num_pvl                2440 non-null   object
#  6   status                 5000 non-null   object
#  7   num_processo           3673 non-null   object
#  8   data_protocolo         3673 non-null   object
#  9   tipo_operacao          5000 non-null   object
#  10  finalidade             5000 non-null   object
#  11  tipo_credor            5000 non-null   object
#  12  credor                 5000 non-null   object
#  13  moeda                  5000 non-null   object
#  14  valor                  5000 non-null   float64
#  15  pvl_assoc_divida       5000 non-null   int64
#  16  pvl_contradado_credor  5000 non-null   int64
#  17  data_status            5000 non-null   object
# dtypes: float64(1), int64(4), object(13)
# memory usage: 703.3+ KB

# %%
df['data_status'].head()
# Out:
# 0    27/07/2011
# 1    19/12/2003
# 2    04/02/2004
# 3    22/10/2013
# 4    30/04/2008
# Name: data_status, dtype: object

# %%
df['ano'] = df['data_status'].str.extract('(\d{4})')

# %%
df['ano'].head()
# Out:
# 0    2011
# 1    2003
# 2    2004
# 3    2013
# 4    2008
# Name: ano, dtype: object

# %% [markdown]
# ####  2) Melhorando a interação com o API
# Observe dois URLs de consultas diferentes, por exemplo o URL utilizado em aula, e o URL feito no exercício anterior. Compare-os e observe as diferenças.
#
# 1. Faça uma função em Python que recebe como argumento o UF da consulta e o tipo de interessado (```'Estado'```ou ```Município```), e que devolve os dados da consulta no formato *DataFrame*.
# 2. Quantas solicitações para o Estado podem ser consultadas para Minas Gerais com *status* em 'Arquivado por decurso de prazo' estão registradas?
# 3. Qual é o município da Bahia com mais solicitações deferidas?
# 4. Salve um arquivo .csv com os dados de solicitações da Bahia, com interessado = 'Estado'

# %%
#1) Seu código aqui
def consulta_dados(uf, tipo_interessado):
    dados_filtrados = df[(df['uf'] == uf) & (df['tipo_interessado'] == tipo_interessado)]
    return dados_filtrados

# %%
# testando a função
uf_consulta = 'SP'
tipo_interessado_consulta = 'Estado'
resultado_consulta = consulta_dados(uf_consulta, tipo_interessado_consulta)
resultado_consulta
# Out:
#       id_pleito tipo_interessado interessado  cod_ibge  uf  \
# 95        58411           Estado   São Paulo        35  SP
# 590       60909           Estado   São Paulo        35  SP
# 651       67175           Estado   São Paulo        35  SP
# 794       11458           Estado   São Paulo        35  SP
# 994       10380           Estado   São Paulo        35  SP
# 1060      11522           Estado   São Paulo        35  SP
# 1472      10502           Estado   São Paulo        35  SP
# 1498      11390           Estado   São Paulo        35  SP
# 1660       8098           Estado   São Paulo        35  SP
# 2992      63653           Estado   São Paulo        35  SP
# 3731       4931           Estado   São Paulo        35  SP
# 3822       7053           Estado   São Paulo        35  SP
# 3842       5223           Estado   São Paulo        35  SP
# 3941       7118           Estado   São Paulo        35  SP
# 4005      31195           Estado   São Paulo        35  SP
# 4292       6536           Estado   São Paulo        35  SP
# 4325      11169           Estado   São Paulo        35  SP
# 4548      12427           Estado   São Paulo        35  SP
# 4920      18661           Estado   São Paulo        35  SP
# 4923       7947           Estado   São Paulo        35  SP
#
#                    num_pvl                                             status  \
# 95    PVL02.001041/2022-17                                           Deferido
# 590   PVL02.007161/2022-28  Encaminhado à PGFN com manifestação técnica fa...
# 651   PVL02.003851/2023-99  Encaminhado à PGFN com manifestação técnica fa...
# 794                   None  Encaminhado à PGFN com manifestação técnica fa...
# 994                   None                                           Deferido
# 1060                  None  Encaminhado à PGFN com manifestação técnica fa...
# 1472                  None  Encaminhado à PGFN com manifestação técnica fa...
# 1498                  None  Encaminhado à PGFN com manifestação técnica fa...
# 1660                  None                                           Deferido
# 2992  PVL02.009168/2022-84                                           Deferido
# 3731                  None  Encaminhado à PGFN com manifestação técnica fa...
# 3822                  None  Encaminhado à PGFN com manifestação técnica fa...
# 3842                  None  Encaminhado à PGFN com manifestação técnica fa...
# 3941                  None  Encaminhado à PGFN com manifestação técnica fa...
# 4005  PVL02.000215/2019-29                                           Deferido
# 4292                  None                                           Deferido
# 4325                  None  Encaminhado à PGFN com manifestação técnica fa...
# 4548                  None  Encaminhado à PGFN com manifestação técnica fa...
# 4920  00000.000000/1003-61                                           Deferido
# 4923                  None  Encaminhado à PGFN com manifestação técnica fa...
#
#               num_processo        data_protocolo  \
# 95    17944.101917/2022-97  2022-05-16T20:43:42Z
# 590   17944.102887/2022-36  2023-09-12T17:03:02Z
# 651   17944.105293/2023-68  2024-02-28T17:47:28Z
# 794   17944.001453/2009-42  2009-11-18T02:00:00Z
# 994   17944.001185/2010-01  2010-08-25T03:00:00Z
# 1060  17944.001467/2008-85  2009-03-20T03:00:00Z
# 1472  17944.001216/2013-68  2014-01-23T02:00:00Z
# 1498  17944.001430/2010-71  2011-03-14T03:00:00Z
# 1660  17944.000712/2012-13  2012-05-14T03:00:00Z
# 2992  17944.100901/2023-48  2023-03-16T13:27:41Z
# 3731  10951.001032/2003-98  2003-12-12T02:00:00Z
# 3822  17944.000486/2013-51  2014-01-31T02:00:00Z
# 3842  17944.000063/2010-99  2010-08-18T03:00:00Z
# 3941  17944.000501/2013-61  2014-01-23T02:00:00Z
# 4005  17944.100827/2019-83  2019-03-21T20:50:26Z
# 4292  17944.000375/2012-64  2012-03-16T03:00:00Z
# 4325  17944.001375/2012-81  2012-12-18T02:00:00Z
# 4548  17944.001684/2007-94  2007-12-13T02:00:00Z
# 4920  17944.000345/2015-09  2017-04-24T14:46:59Z
# 4923  17944.000682/2014-15  2014-06-11T03:00:00Z
#
#                                           tipo_operacao  \
# 95                                Concessão de garantia
# 590   Operação contratual externa (com garantia da U...
# 651   Operação contratual interna (com garantia da U...
# 794   Operação contratual externa (com garantia da U...
# 994                         Operação contratual interna
# 1060  Operação contratual externa (com garantia da U...
# 1472  Operação contratual externa (com garantia da U...
# 1498  Operação contratual externa (com garantia da U...
# 1660                        Operação contratual interna
# 2992                              Concessão de garantia
# 3731  Operação contratual externa (com garantia da U...
# 3822  Operação contratual externa (com garantia da U...
# 3842  Operação contratual externa (com garantia da U...
# 3941  Operação contratual externa (com garantia da U...
# 4005                              Concessão de garantia
# 4292                        Operação contratual interna
# 4325  Operação contratual interna (com garantia da U...
# 4548  Operação contratual externa (com garantia da U...
# 4920                        Operação contratual interna
# 4923  Operação contratual externa (com garantia da U...
#
#                                              finalidade  \
# 95    Concessão de garantia a empresa estatal não de...
# 590                                      Multissetorial
# 651                                      Infraestrutura
# 794                                      Infraestrutura
# 994                           PAC - Copa Pró-Transporte
# 1060                                     Infraestrutura
# 1472                                     Infraestrutura
# 1498                Preservação e recuperação ambiental
# 1660                                     Infraestrutura
# 2992  Concessão de garantia a empresa estatal não de...
# 3731                       Fortalecimento Institucional
# 3822                                     Infraestrutura
# 3842                Preservação e recuperação ambiental
# 3941                                     Infraestrutura
# 4005  Concessão de garantia a empresa estatal não de...
# 4292                                     Infraestrutura
# 4325                                         Proinveste
# 4548     Aquisição de máquinas, equipamentos e veículos
# 4920                                     Infraestrutura
# 4923                                     Infraestrutura
#
#                                tipo_credor  \
# 95    Instituição Financeira Internacional
# 590   Instituição Financeira Internacional
# 651        Instituição Financeira Nacional
# 794   Instituição Financeira Internacional
# 994        Instituição Financeira Nacional
# 1060  Instituição Financeira Internacional
# 1472  Instituição Financeira Internacional
# 1498  Instituição Financeira Internacional
# 1660       Instituição Financeira Nacional
# 2992  Instituição Financeira Internacional
# 3731  Instituição Financeira Internacional
# 3822  Instituição Financeira Internacional
# 3842  Instituição Financeira Internacional
# 3941  Instituição Financeira Internacional
# 4005  Instituição Financeira Internacional
# 4292       Instituição Financeira Nacional
# 4325       Instituição Financeira Nacional
# 4548  Instituição Financeira Internacional
# 4920       Instituição Financeira Nacional
# 4923  Instituição Financeira Internacional
#
#                                                  credor          moeda  \
# 95                                 New Development Bank  Dólar dos EUA
# 590             Banco Interamericano de Desenvolvimento  Dólar dos EUA
# 651   Banco Nacional de Desenvolvimento Econômico e ...           Real
# 794   Banco Internacional para Reconstrução e Desenv...  Dólar dos EUA
# 994                             Caixa Econômica Federal           Real
# 1060  Banco Internacional para Reconstrução e Desenv...  Dólar dos EUA
# 1472            Banco Interamericano de Desenvolvimento  Dólar dos EUA
# 1498            Banco Interamericano de Desenvolvimento  Dólar dos EUA
# 1660  Banco Nacional de Desenvolvimento Econômico e ...           Real
# 2992            Banco Interamericano de Desenvolvimento  Dólar dos EUA
# 3731            Banco Interamericano de Desenvolvimento  Dólar dos EUA
# 3822                Agência Francesa de Desenvolvimento           Euro
# 3842            Banco Interamericano de Desenvolvimento  Dólar dos EUA
# 3941                       Corporação Andina de Fomento  Dólar dos EUA
# 4005  Banco Internacional para Reconstrução e Desenv...  Dólar dos EUA
# 4292  Banco Nacional de Desenvolvimento Econômico e ...           Real
# 4325  Banco Nacional de Desenvolvimento Econômico e ...           Real
# 4548  Banco Internacional para Reconstrução e Desenv...  Dólar dos EUA
# 4920  Banco Nacional de Desenvolvimento Econômico e ...           Real
# 4923            Banco Interamericano de Desenvolvimento  Dólar dos EUA
#
#              valor  pvl_assoc_divida  pvl_contradado_credor data_status   ano
# 95    9.000000e+07                 0                      0  31/05/2022  2022
# 590   1.642373e+08                 0                      0  27/09/2023  2023
# 651   3.605000e+09                 0                      0  14/03/2024  2024
# 794   6.504120e+08                 1                      0  25/11/2009  2009
# 994   1.082000e+09                 1                      0  30/08/2010  2010
# 1060  1.666500e+08                 1                      0  27/03/2009  2009
# 1472  4.801350e+08                 1                      0  27/02/2014  2014
# 1498  1.157000e+08                 1                      0  06/04/2011  2011
# 1660  5.500000e+08                 1                      0  04/06/2012  2012
# 2992  1.100000e+08                 0                      0  24/03/2023  2023
# 3731  2.000000e+07                 1                      0  07/07/2004  2004
# 3822  3.000000e+08                 1                      0  05/03/2014  2014
# 3842  1.624540e+08                 1                      0  25/08/2010  2010
# 3941  2.040000e+08                 1                      0  27/02/2014  2014
# 4005  2.500000e+08                 1                      0  01/04/2019  2019
# 4292  9.220000e+08                 1                      0  19/04/2012  2012
# 4325  1.958620e+09                 1                      0  03/01/2013  2013
# 4548  5.500000e+08                 1                      0  13/05/2008  2008
# 4920  4.759899e+08                 1                      0  10/05/2017  2017
# 4923  4.801350e+08                 1                      0  15/08/2014  2014

# %%
# 2) Seu código aqui
uf_consulta = 'MG'
tipo_interessado_consulta = 'Estado'
resultado_consulta = consulta_dados(uf_consulta, tipo_interessado_consulta)
resultado_consulta
# Out:
#       id_pleito tipo_interessado   interessado  cod_ibge  uf num_pvl  \
# 317       10338           Estado  Minas Gerais        31  MG    None
# 2230      13602           Estado  Minas Gerais        31  MG    None
# 2468      10011           Estado  Minas Gerais        31  MG    None
# 3027       6811           Estado  Minas Gerais        31  MG    None
# 4757      12286           Estado  Minas Gerais        31  MG    None
#
#                                                  status          num_processo  \
# 317   Encaminhado à PGFN com manifestação técnica fa...  17944.001175/2009-23
# 2230  Encaminhado à PGFN com manifestação técnica fa...  19405.000034/2005-92
# 2468                                           Deferido  17944.001099/2010-90
# 3027  Encaminhado à PGFN com manifestação técnica fa...  17944.000435/2008-62
# 4757                                          Arquivado  17944.001650/2008-81
#
#             data_protocolo                                      tipo_operacao  \
# 317   2009-09-22T03:00:00Z  Operação contratual interna (com garantia da U...
# 2230  2005-10-31T02:00:00Z  Operação contratual externa (com garantia da U...
# 2468  2010-08-23T03:00:00Z                        Operação contratual interna
# 3027  2008-03-06T03:00:00Z  Operação contratual externa (com garantia da U...
# 4757  2008-12-31T02:00:00Z  Operação contratual externa (com garantia da U...
#
#                                              finalidade  \
# 317   PEF - Programa Emergencial de Financiamento do...
# 2230                                     Infraestrutura
# 2468                                               PMAE
# 3027                                     Multissetorial
# 4757                                     Infraestrutura
#
#                                tipo_credor  \
# 317        Instituição Financeira Nacional
# 2230  Instituição Financeira Internacional
# 2468       Instituição Financeira Nacional
# 3027  Instituição Financeira Internacional
# 4757  Instituição Financeira Internacional
#
#                                                  credor          moeda  \
# 317                                 Banco do Brasil S/A           Real
# 2230            Banco Interamericano de Desenvolvimento  Dólar dos EUA
# 2468  Banco Nacional de Desenvolvimento Econômico e ...           Real
# 3027  Banco Internacional para Reconstrução e Desenv...  Dólar dos EUA
# 4757            Banco Interamericano de Desenvolvimento  Dólar dos EUA
#
#              valor  pvl_assoc_divida  pvl_contradado_credor data_status   ano
# 317   1.781800e+08                 1                      0  08/10/2009  2009
# 2230  5.000000e+07                 1                      0  18/04/2006  2006
# 2468  4.674243e+06                 1                      0  25/08/2010  2010
# 3027  9.760000e+08                 1                      0  02/07/2008  2008
# 4757  5.000000e+07                 0                      0  23/01/2009  2009

# %%
resultado_consulta['status'].value_counts()
# Out:
# status
# Encaminhado à PGFN com manifestação técnica favorável    3
# Deferido                                                 1
# Arquivado                                                1
# Name: count, dtype: int64

# %%
status_MG = resultado_consulta['status'] == 'Arquivado por decurso de prazo'
status_MG.value_counts()
# Out:
# status
# False    5
# Name: count, dtype: int64

# %%
# 3) Seu código aqui
uf_consulta = 'BA'
tipo_interessado_consulta = 'Município'
resultado_consulta = consulta_dados(uf_consulta, tipo_interessado_consulta)

# %%
resultado_consulta['status'].value_counts()
# Out:
# status
# Deferido                                                 79
# Deferido (PVL-IF)                                        39
# Arquivado por decurso de prazo                           24
# Arquivado                                                23
# Regularizado                                              7
# Arquivado a pedido                                        6
# Encaminhado à PGFN com manifestação técnica favorável     5
# Em retificação pelo interessado                           4
# Encaminhado à PGFN (decisão judicial)                     1
# Arquivado a pedido (PVL-IF)                               1
# Pendente de regularização                                 1
# Em análise                                                1
# Name: count, dtype: int64

# %%
deferido_data = resultado_consulta[resultado_consulta['status'] == 'Deferido']

# %%
deferido_data
# Out:
#       id_pleito tipo_interessado                  interessado  cod_ibge  uf  \
# 66        64288        Município                    Itamaraju   2915601  BA
# 151       54329        Município                        Irecê   2914604  BA
# 176       50929        Município                   Maragogipe   2920601  BA
# 285       10235        Município       Luís Eduardo Magalhães   2919553  BA
# 286       10239        Município                      Caetité   2905206  BA
# ...         ...              ...                          ...       ...  ..
# 4806      18631        Município               Cruz Das Almas   2909802  BA
# 4808      18640        Município  Livramento de Nossa Senhora   2919504  BA
# 4909      11146        Município                  Serra Preta   2930402  BA
# 4922      11166        Município            Bom Jesus da Lapa   2903904  BA
# 4971      25494        Município                      Guajeru   2911659  BA
#
#                    num_pvl    status          num_processo  \
# 66    PVL02.001151/2023-60  Deferido  17944.101895/2023-46
# 151   PVL02.001295/2022-35  Deferido  17944.100706/2022-37
# 176   PVL02.005401/2021-79  Deferido  17944.104472/2021-16
# 285                   None  Deferido  17944.001151/2010-16
# 286                   None  Deferido  17944.001152/2010-52
# ...                    ...       ...                   ...
# 4806                  None  Deferido  19407.000072/2003-63
# 4808                  None  Deferido  19407.000077/2002-13
# 4909                  None  Deferido  17944.001371/2008-17
# 4922                  None  Deferido  17944.001375/2009-86
# 4971  00000.000000/2029-02  Deferido  17944.000837/2017-58
#
#             data_protocolo                tipo_operacao  \
# 66    2023-05-12T19:48:42Z  Operação contratual interna
# 151   2022-03-09T23:16:42Z  Operação contratual interna
# 176   2021-12-15T21:11:48Z  Operação contratual interna
# 285   2011-04-11T03:00:00Z  Operação contratual interna
# 286   2011-08-17T03:00:00Z  Operação contratual interna
# ...                    ...                          ...
# 4806  2003-12-31T02:00:00Z  Operação contratual interna
# 4808  2003-08-31T03:00:00Z  Operação contratual interna
# 4909  2009-11-06T02:00:00Z  Operação contratual interna
# 4922  2010-09-08T03:00:00Z  Operação contratual interna
# 4971  2017-09-28T17:43:57Z  Operação contratual interna
#
#                                           finalidade  \
# 66                                    Infraestrutura
# 151                                   Infraestrutura
# 176                                   Infraestrutura
# 285   Aquisição de máquinas, equipamentos e veículos
# 286   Aquisição de máquinas, equipamentos e veículos
# ...                                              ...
# 4806  Aquisição de máquinas, equipamentos e veículos
# 4808  Aquisição de máquinas, equipamentos e veículos
# 4909  Aquisição de máquinas, equipamentos e veículos
# 4922                                    Provias 2009
# 4971                                  Infraestrutura
#
#                           tipo_credor  \
# 66    Instituição Financeira Nacional
# 151   Instituição Financeira Nacional
# 176   Instituição Financeira Nacional
# 285   Instituição Financeira Nacional
# 286   Instituição Financeira Nacional
# ...                               ...
# 4806  Instituição Financeira Nacional
# 4808  Instituição Financeira Nacional
# 4909  Instituição Financeira Nacional
# 4922  Instituição Financeira Nacional
# 4971  Instituição Financeira Nacional
#
#                                          credor moeda       valor  \
# 66                      Caixa Econômica Federal  Real  30000000.0
# 151                     Caixa Econômica Federal  Real  12000000.0
# 176                     Caixa Econômica Federal  Real  15000000.0
# 285   Agência de Fomento do Estado da Bahia S/A  Real    130000.0
# 286   Agência de Fomento do Estado da Bahia S/A  Real    130000.0
# ...                                         ...   ...         ...
# 4806  Agência de Fomento do Estado da Bahia S/A  Real    500000.0
# 4808  Agência de Fomento do Estado da Bahia S/A  Real    240000.0
# 4909  Agência de Fomento do Estado da Bahia S/A  Real     65000.0
# 4922                        Banco do Brasil S/A  Real   3000000.0
# 4971  Agência de Fomento do Estado da Bahia S/A  Real    940755.0
#
#       pvl_assoc_divida  pvl_contradado_credor data_status   ano
# 66                   0                      1  17/05/2023  2023
# 151                  0                      1  10/03/2022  2022
# 176                  0                      1  20/12/2021  2021
# 285                  1                      0  29/04/2011  2011
# 286                  1                      0  14/10/2011  2011
# ...                ...                    ...         ...   ...
# 4806                 0                      0  23/01/2004  2004
# 4808                 0                      0  29/09/2003  2003
# 4909                 0                      0  26/11/2009  2009
# 4922                 0                      0  30/09/2010  2010
# 4971                 0                      0  06/10/2017  2017
#
# [79 rows x 19 columns]

# %%
contagem_deferido_por_municipio = deferido_data['interessado'].value_counts() #contando a frequencia dos municipios que aparecem
contagem_deferido_por_municipio.head()
# Out:
# interessado
# Luís Eduardo Magalhães    3
# Teixeira de Freitas       3
# Salvador                  2
# Caetité                   2
# Camaçari                  2
# Name: count, dtype: int64

# %%
# 4) Seu código aqui
uf_consulta = 'BA'
tipo_interessado_consulta = 'Estado'
resultado_consulta = consulta_dados(uf_consulta, tipo_interessado_consulta)
resultado_consulta.to_csv('Solicitações_Bahia.csv')
